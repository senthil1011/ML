# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Data Loading:
path="C:/Users/SENTS-IN/Desktop/Training/"
df = pd.read_csv(path+"prisoners.csv")

# %%
df
# Out:
#              STATE/UT  YEAR  \
# 0      Andhra Pradesh  2013
# 1   Arunachal Pradesh  2013
# 2               Assam  2013
# 3               Bihar  2013
# 4         Chhatisgarh  2013
# 5                 Goa  2013
# 6             Gujarat  2013
# 7             Haryana  2013
# 8    Himachal Pradesh  2013
# 9     Jammu & Kashmir  2013
# 10          Jharkhand  2013
# 11          Karnataka  2013
# 12             Kerala  2013
# 13     Madhya Pradesh  2013
# 14        Maharashtra  2013
# 15            Manipur  2013
# 16          Meghalaya  2013
# 17            Mizoram  2013
# 18           Nagaland  2013
# 19             Orissa  2013
# 20             Punjab  2013
# 21          Rajasthan  2013
# 22             Sikkim  2013
# 23          Tamilnadu  2013
# 24            Tripura  2013
# 25      Uttar Pradesh  2013
# 26        Uttaranchal  2013
# 27        West Bengal  2013
# 28      A & N Islands  2013
# 29         Chandigarh  2013
# 30       D & N Haveli  2013
# 31        Daman & Diu  2013
# ...

# %%
"""
Load the dataset “prisoners.csv” using pandas and display the first and
last five rows in the dataset. [Hint: Refer to read_csv,head and tail methods in pandas]
"""
# Out:
# '\nLoad the dataset “prisoners.csv” using pandas and display the first and\nlast five rows in the dataset. [Hint: Refer to read_csv,head and tail methods in pandas]\n'

# %%
df_1=pd.concat([df.head(5),df.tail(5)])

# %%
df_1
# Out:
#              STATE/UT  YEAR  \
# 0      Andhra Pradesh  2013
# 1   Arunachal Pradesh  2013
# 2               Assam  2013
# 3               Bihar  2013
# 4         Chhatisgarh  2013
# 30       D & N Haveli  2013
# 31        Daman & Diu  2013
# 32              Delhi  2013
# 33        Lakshadweep  2013
# 34        Pondicherry  2013
#
#     No. of Inmates benefitted by Elementary Education  \
# 0                                                9480
# 1                                                   0
# 2                                                 676
# 3                                                1693
# 4                                                1664
# 30                                                  0
# 31                                                  0
# 32                                               1458
# 33                                                  0
# 34                                                  0
#
# ...

# %%
df.describe()
# Out:
#          YEAR  No. of Inmates benefitted by Elementary Education  \
# count    35.0                                          35.000000
# mean   2013.0                                        1057.914286
# std       0.0                                        2078.196777
# min    2013.0                                           0.000000
# 25%    2013.0                                           0.000000
# 50%    2013.0                                         167.000000
# 75%    2013.0                                        1294.500000
# max    2013.0                                        9480.000000
#
#        No. of Inmates benefitted by Adult Education  \
# count                                     35.000000
# mean                                    1534.857143
# std                                     3022.110503
# min                                        0.000000
# 25%                                        6.500000
# 50%                                      237.000000
# ...

# %%
"""
b.Use describe method in pandas and find out the number of columns. Can you say something about 
those rows who have zero inmates?
[Hint: Use the loc attribute of dataframe combined with conditional checks]
"""
df.loc[(df['No. of Inmates benefitted by Elementary Education']==0)|
       (df['No. of Inmates benefitted by Adult Education']     ==0)|
       (df['No. of Inmates benefitted by Higher Education']    ==0)|
       (df['No. of Inmates benefitted by Computer Course' ]    ==0)]
# Out:
#              STATE/UT  YEAR  \
# 1   Arunachal Pradesh  2013
# 5                 Goa  2013
# 8    Himachal Pradesh  2013
# 15            Manipur  2013
# 16          Meghalaya  2013
# 17            Mizoram  2013
# 18           Nagaland  2013
# 22             Sikkim  2013
# 28      A & N Islands  2013
# 29         Chandigarh  2013
# 30       D & N Haveli  2013
# 31        Daman & Diu  2013
# 33        Lakshadweep  2013
# 34        Pondicherry  2013
#
#     No. of Inmates benefitted by Elementary Education  \
# 1                                                   0
# 5                                                   7
# 8                                                  33
# 15                                                  0
# 16                                                  1
# 17                                                  0
# 18                                                  0
# 22                                                  0
# ...

# %%
#Data Manipulation:

# %%
"""
.Create a new column -’total_benefitted’ that is a sum of inmates benefitted through all modes.
[Hint: Use sum method with appropriate axis]
"""
# Out:
# '\n.Create a new column -’total_benefitted’ that is a sum of inmates benefitted through all modes.\n[Hint: Use sum method with appropriate axis]\n'

# %%
df
# Out:
#              STATE/UT  YEAR  \
# 0      Andhra Pradesh  2013
# 1   Arunachal Pradesh  2013
# 2               Assam  2013
# 3               Bihar  2013
# 4         Chhatisgarh  2013
# 5                 Goa  2013
# 6             Gujarat  2013
# 7             Haryana  2013
# 8    Himachal Pradesh  2013
# 9     Jammu & Kashmir  2013
# 10          Jharkhand  2013
# 11          Karnataka  2013
# 12             Kerala  2013
# 13     Madhya Pradesh  2013
# 14        Maharashtra  2013
# 15            Manipur  2013
# 16          Meghalaya  2013
# 17            Mizoram  2013
# 18           Nagaland  2013
# 19             Orissa  2013
# 20             Punjab  2013
# 21          Rajasthan  2013
# 22             Sikkim  2013
# 23          Tamilnadu  2013
# 24            Tripura  2013
# 25      Uttar Pradesh  2013
# 26        Uttaranchal  2013
# 27        West Bengal  2013
# 28      A & N Islands  2013
# 29         Chandigarh  2013
# 30       D & N Haveli  2013
# 31        Daman & Diu  2013
# ...

# %%
df1=df.drop(['YEAR'], axis=1)

# %%
df1['total_benefitted']=df1.sum(axis=1)

# %%
df1
# Out:
#              STATE/UT  No. of Inmates benefitted by Elementary Education  \
# 0      Andhra Pradesh                                               9480
# 1   Arunachal Pradesh                                                  0
# 2               Assam                                                676
# 3               Bihar                                               1693
# 4         Chhatisgarh                                               1664
# 5                 Goa                                                  7
# 6             Gujarat                                               2310
# 7             Haryana                                               1131
# 8    Himachal Pradesh                                                 33
# 9     Jammu & Kashmir                                                102
# 10          Jharkhand                                               3008
# 11          Karnataka                                                633
# ...

# %%
"""
b.Create a new row -“totals” that is the sum of all inmates benefitted through each mode across all states
"""
# Out:
# '\nb.Create a new row -“totals” that is the sum of all inmates benefitted through each mode across all states\n'

# %%
df2=df.drop(['YEAR'], axis=1)

# %%
df2.loc['total']=df2.sum(axis=0)

# %%
df2
# Out:
#                                                 STATE/UT  \
# 0                                         Andhra Pradesh
# 1                                      Arunachal Pradesh
# 2                                                  Assam
# 3                                                  Bihar
# 4                                            Chhatisgarh
# 5                                                    Goa
# 6                                                Gujarat
# 7                                                Haryana
# 8                                       Himachal Pradesh
# 9                                        Jammu & Kashmir
# 10                                             Jharkhand
# 11                                             Karnataka
# 12                                                Kerala
# 13                                        Madhya Pradesh
# 14                                           Maharashtra
# ...

# %%
df2.iloc[-1,0]
# Out:
# 'Andhra PradeshArunachal PradeshAssamBiharChhatisgarhGoaGujaratHaryanaHimachal PradeshJammu & KashmirJharkhandKarnatakaKeralaMadhya PradeshMaharashtraManipurMeghalayaMizoramNagalandOrissaPunjabRajasthanSikkimTamilnaduTripuraUttar PradeshUttaranchalWest BengalA & N IslandsChandigarhD & N HaveliDaman & DiuDelhiLakshadweepPondicherry'

# %%
df2.iloc[-1,0]="Total"

# %%
df2
# Out:
#                 STATE/UT  No. of Inmates benefitted by Elementary Education  \
# 0         Andhra Pradesh                                               9480
# 1      Arunachal Pradesh                                                  0
# 2                  Assam                                                676
# 3                  Bihar                                               1693
# 4            Chhatisgarh                                               1664
# 5                    Goa                                                  7
# 6                Gujarat                                               2310
# 7                Haryana                                               1131
# 8       Himachal Pradesh                                                 33
# 9        Jammu & Kashmir                                                102
# 10             Jharkhand                                               3008
# ...

# %%
#Plotting:

# %%
"""
Make a bar plot with each state name on the x -axis and their total benefitted inmates astheir bar heights.
Which state has the maximum number of beneficiaries?[Hint: Use bar method of pyplot]
"""
# Out:
# '\nMake a bar plot with each state name on the x -axis and their total benefitted inmates astheir bar heights.\nWhich state has the maximum number of beneficiaries?[Hint: Use bar method of pyplot]\n'

# %%
df
# Out:
#              STATE/UT  YEAR  \
# 0      Andhra Pradesh  2013
# 1   Arunachal Pradesh  2013
# 2               Assam  2013
# 3               Bihar  2013
# 4         Chhatisgarh  2013
# 5                 Goa  2013
# 6             Gujarat  2013
# 7             Haryana  2013
# 8    Himachal Pradesh  2013
# 9     Jammu & Kashmir  2013
# 10          Jharkhand  2013
# 11          Karnataka  2013
# 12             Kerala  2013
# 13     Madhya Pradesh  2013
# 14        Maharashtra  2013
# 15            Manipur  2013
# 16          Meghalaya  2013
# 17            Mizoram  2013
# 18           Nagaland  2013
# 19             Orissa  2013
# 20             Punjab  2013
# 21          Rajasthan  2013
# 22             Sikkim  2013
# 23          Tamilnadu  2013
# 24            Tripura  2013
# 25      Uttar Pradesh  2013
# 26        Uttaranchal  2013
# 27        West Bengal  2013
# 28      A & N Islands  2013
# 29         Chandigarh  2013
# 30       D & N Haveli  2013
# 31        Daman & Diu  2013
# ...

# %%
x=df1['STATE/UT']
y=df1['total_benefitted']
plt.bar(x,y)
# Out:
# <BarContainer object of 35 artists>

# %%
df3=df1[df1['total_benefitted']==df1['total_benefitted'].max()]

# %%
df3['STATE/UT']
# Out:
# 0    Andhra Pradesh
# Name: STATE/UT, dtype: object

# %%
"""
Make a pie chart that depicts the ratio among different modes of benefits.
"""
# Out:
# '\nMake a pie chart that depicts the ratio among different modes of benefits.\n'

# %%
#df3.plt.pie(y='total_benefitted', figsize=(5,5))

# %%
df_pie=df2[-1:]

# %%
df_pie
# Out:
#       STATE/UT  No. of Inmates benefitted by Elementary Education  \
# total    Total                                              37027
#
#        No. of Inmates benefitted by Adult Education  \
# total                                         53720
#
#        No. of Inmates benefitted by Higher Education  \
# total                                           8311
#
#        No. of Inmates benefitted by Computer Course
# total                                          7356

# %%
labels = ["No. of Inmates benefitted by Elementary Education","No. of Inmates benefitted by Adult Education","No. of Inmates benefitted by Higher Education","No. of Inmates benefitted by Computer Course"]
sizes = [37027,53720,8311,7356]
plt.pie(sizes, labels=labels, autopct='%1.1f%%',shadow=True, startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x2515635cc08>,
# ...
#  [Text(-0.9768743831801681, 0.5056841301507953, 'No. of Inmates benefitted by Elementary Education'),
#   Text(0.6485904100325619, -0.8884427274809521, 'No. of Inmates benefitted by Adult Education'),
#   Text(0.6914098416273148, 0.8555421853426585, 'No. of Inmates benefitted by Higher Education'),
#   Text(0.2370096886102041, 1.07416311959818, 'No. of Inmates benefitted by Computer Course')],
#  [Text(-0.532840572643728, 0.2758277073549792, '34.8%'),
#   Text(0.3537765872904883, -0.48460512408051926, '50.5%'),
#   Text(0.3771326408876262, 0.4666593738232682, '7.8%'),
#   Text(0.12927801196920222, 0.5859071561444618, '6.9%')])
